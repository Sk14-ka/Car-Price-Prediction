# %%
#importing library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading the files
df = pd.read_csv("car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.shape
# Out:
# (301, 9)

# %% [markdown]
# ## Data Types

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %% [markdown]
# ## Describe function

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.describe(include='all')
# Out:
#        Car_Name         Year  Selling_Price  Present_Price     Kms_Driven  \
# count       301   301.000000     301.000000     301.000000     301.000000
# unique       98          NaN            NaN            NaN            NaN
# top        city          NaN            NaN            NaN            NaN
# freq         26          NaN            NaN            NaN            NaN
# mean        NaN  2013.627907       4.661296       7.628472   36947.205980
# std         NaN     2.891554       5.082812       8.644115   38886.883882
# min         NaN  2003.000000       0.100000       0.320000     500.000000
# 25%         NaN  2012.000000       0.900000       1.200000   15000.000000
# 50%         NaN  2014.000000       3.600000       6.400000   32000.000000
# 75%         NaN  2016.000000       6.000000       9.900000   48767.000000
# max         NaN  2018.000000      35.000000      92.600000  500000.000000
#
#        Fuel_Type Seller_Type Transmission       Owner
# count        301         301          301  301.000000
# unique         3           2            2         NaN
# top       Petrol      Dealer       Manual         NaN
# freq         239         195          261         NaN
# mean         NaN         NaN          NaN    0.043189
# std          NaN         NaN          NaN    0.247915
# min          NaN         NaN          NaN    0.000000
# 25%          NaN         NaN          NaN    0.000000
# 50%          NaN         NaN          NaN    0.000000
# 75%          NaN         NaN          NaN    0.000000
# max          NaN         NaN          NaN    3.000000

# %% [markdown]
# ## Isnull Function

# %%
#count the number of missing values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# **Their is no null value in the dataset**.

# %% [markdown]
# ## Unique Function

# %%
df.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
temp = pd.DataFrame(index = df.columns)
temp['DataType']=df.dtypes
temp['null_count']=df.isnull().sum()
temp['unique_count']=df.nunique()

# %%
temp
# Out:
#               DataType  null_count  unique_count
# Car_Name        object           0            98
# Year             int64           0            16
# Selling_Price  float64           0           156
# Present_Price  float64           0           147
# Kms_Driven       int64           0           206
# Fuel_Type       object           0             3
# Seller_Type     object           0             2
# Transmission    object           0             2
# Owner            int64           0             3

# %%
final_dataset = df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven','Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %% [markdown]
# - In the dataset for prediction their is no requirement of car name so we drop it

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_dataset['Current_Year']=2020

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2020
# 1       Manual      0          2020
# 2       Manual      0          2020
# 3       Manual      0          2020
# 4       Manual      0          2020

# %%
final_dataset['no_year']=final_dataset['Current_Year']-final_dataset['Year']

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  no_year
# 0       Manual      0          2020        6
# 1       Manual      0          2020        7
# 2       Manual      0          2020        3
# 3       Manual      0          2020        9
# 4       Manual      0          2020        6

# %%
final_dataset.drop(['Year'],axis=1,inplace=True)
final_dataset.drop(['Current_Year'],axis=1,inplace=True)

# %% [markdown]
# - Hence no of year is present so 'Year' and 'Current Year' is useless

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no_year
# 0       Manual      0        6
# 1       Manual      0        7
# 2       Manual      0        3
# 3       Manual      0        9
# 4       Manual      0        6

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Plotting HIstogram

# %%
final_dataset['Kms_Driven'].plot.hist(bins=50)

# %%
final_dataset.plot.hist(bins=50)

# %% [markdown]
# ## Using one hot encoding to convert continuous value

# %%
final_dataset = pd.get_dummies(final_dataset)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_CNG  \
# 0           3.35           5.59       27000      0        6              0
# 1           4.75           9.54       43000      0        7              0
# 2           7.25           9.85        6900      0        3              0
# 3           2.85           4.15        5200      0        9              0
# 4           4.60           6.87       42450      0        6              0
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0                 0                 1                   1
# 1                 1                 0                   1
# 2                 0                 1                   1
# 3                 0                 1                   1
# 4                 1                 0                   1
#
#    Seller_Type_Individual  Transmission_Automatic  Transmission_Manual
# 0                       0                       0                    1
# 1                       0                       0                    1
# 2                       0                       0                    1
# 3                       0                       0                    1
# 4                       0                       0                    1

# %%
final_dataset.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'no_year',
#        'Fuel_Type_CNG', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol',
#        'Seller_Type_Dealer', 'Seller_Type_Individual',
#        'Transmission_Automatic', 'Transmission_Manual'],
#       dtype='object')

# %%
final_dataset.shape
# Out:
# (301, 12)

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# no_year                     -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_CNG               -0.025164      -0.011500    0.012223 -0.014272
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Dealer           0.550724       0.512030    0.101419 -0.124269
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Automatic       0.367128       0.348715    0.162510  0.050316
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                          no_year  Fuel_Type_CNG  Fuel_Type_Diesel  \
# Selling_Price          -0.236141      -0.025164          0.552339
# Present_Price           0.047584      -0.011500          0.473306
# Kms_Driven              0.524342       0.012223          0.172515
# Owner                   0.182104      -0.014272         -0.053469
# no_year                 1.000000       0.017790         -0.064315
# Fuel_Type_CNG           0.017790       1.000000         -0.040808
# Fuel_Type_Diesel       -0.064315      -0.040808          1.000000
# Fuel_Type_Petrol        0.059959      -0.160577         -0.979648
# Seller_Type_Dealer     -0.039896       0.060300          0.350467
# Seller_Type_Individual  0.039896      -0.060300         -0.350467
# Transmission_Automatic  0.000394      -0.032018          0.098643
# Transmission_Manual    -0.000394       0.032018         -0.098643
#
#                         Fuel_Type_Petrol  Seller_Type_Dealer  \
# Selling_Price                  -0.540571            0.550724
# Present_Price                  -0.465244            0.512030
# Kms_Driven                     -0.172874            0.101419
# Owner                           0.055687           -0.124269
# no_year                         0.059959           -0.039896
# Fuel_Type_CNG                  -0.160577            0.060300
# Fuel_Type_Diesel               -0.979648            0.350467
# Fuel_Type_Petrol                1.000000           -0.358321
# Seller_Type_Dealer             -0.358321            1.000000
# Seller_Type_Individual          0.358321           -1.000000
# Transmission_Automatic         -0.091013            0.063240
# Transmission_Manual             0.091013           -0.063240
#
#                         Seller_Type_Individual  Transmission_Automatic  \
# Selling_Price                        -0.550724                0.367128
# Present_Price                        -0.512030                0.348715
# Kms_Driven                           -0.101419                0.162510
# Owner                                 0.124269                0.050316
# no_year                               0.039896                0.000394
# Fuel_Type_CNG                        -0.060300               -0.032018
# Fuel_Type_Diesel                     -0.350467                0.098643
# Fuel_Type_Petrol                      0.358321               -0.091013
# Seller_Type_Dealer                   -1.000000                0.063240
# Seller_Type_Individual                1.000000               -0.063240
# Transmission_Automatic               -0.063240                1.000000
# Transmission_Manual                   0.063240               -1.000000
#
#                         Transmission_Manual
# Selling_Price                     -0.367128
# Present_Price                     -0.348715
# Kms_Driven                        -0.162510
# Owner                             -0.050316
# no_year                           -0.000394
# Fuel_Type_CNG                      0.032018
# Fuel_Type_Diesel                  -0.098643
# Fuel_Type_Petrol                   0.091013
# Seller_Type_Dealer                -0.063240
# Seller_Type_Individual             0.063240
# Transmission_Automatic            -1.000000
# Transmission_Manual                1.000000

# %%
sns.pairplot(final_dataset)

# %%
#plotting correlation between all the features
corrmat = final_dataset.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
sns.heatmap(final_dataset[top_corr_features].corr(),annot=True,cmap='RdYlGn')

# %% [markdown]
# ## Segregate the Independent and Dependent variable

# %%
x=final_dataset.drop(['Selling_Price'],axis=1)
y=final_dataset['Selling_Price']
x.shape,y.shape
# Out:
# ((301, 11), (301,))

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
###Features Importance
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor(n_estimators=100,min_samples_leaf=1,min_samples_split=2,random_state=56)
model.fit(x,y)
# Out:
# ExtraTreesRegressor(random_state=56)

# %%
print(model.feature_importances_)
# Out:
# [3.69159632e-01 4.05506161e-02 1.38755233e-03 7.89008465e-02
#  1.06982989e-04 2.22056592e-01 1.22278047e-02 1.24199926e-01
#  7.90522642e-03 7.30475981e-02 7.04572232e-02]

# %%
#plot the graph on features_importance for better visualization
feature_importance = pd.Series(model.feature_importances_,index=x.columns)
feature_importance.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# ## Train_Test_Split

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=42)
train_x.shape,train_y.shape,test_x.shape,test_y.shape
# Out:
# ((240, 11), (240,), (61, 11), (61,))

# %%
train_x.head()
# Out:
#      Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_CNG  \
# 184          0.750       26000      1       12              0
# 132          0.950        3500      0        3              0
# 194          0.787       50000      0       12              0
# 75           6.800       36000      0        5              0
# 111          1.500        8700      0        4              0
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 184                 0                 1                   0
# 132                 0                 1                   0
# 194                 0                 1                   0
# 75                  0                 1                   1
# 111                 0                 1                   0
#
#      Seller_Type_Individual  Transmission_Automatic  Transmission_Manual
# 184                       1                       0                    1
# 132                       1                       0                    1
# 194                       1                       0                    1
# 75                        0                       0                    1
# 111                       1                       0                    1

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor
rr = RandomForestRegressor(random_state=101)

# %%
### Hyperparameters

#number of trees in random forest 
n_estimators = [int(x) for x in np.linspace(start =100,stop=1200,num = 12)]

#number of features to consider at every split
max_features=['auto','sqrt']

#Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5,30,num=6)]

#max_deppth.append(none)

#minimum number of samples required to split a node
min_samples_split = [2,5,10,15,100]

#minimum number of samples required at each leaf node 
min_samples_leaf = [1,2,5,10]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
#create random_grid\
random_grid = {'n_estimators':n_estimators,'max_features':max_features,'max_depth':max_depth,'min_samples_split':min_samples_split,'min_samples_leaf':min_samples_leaf}

# %%
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rr_random = RandomizedSearchCV(estimator=rr,param_distributions = random_grid,scoring='neg_mean_squared_error',n_iter = 10, cv = 10,verbose = 2,random_state=56,n_jobs=1)

# %%
rr_random.fit(train_x,train_y)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   0.3s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   0.3s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   0.3s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   0.3s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   0.3s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   0.3s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   0.3s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.3s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.4s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.3s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.3s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.3s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.3s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.4s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.4s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.3s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, total=   0.3s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=   0.6s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=   0.7s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=   0.6s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=   0.6s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=   0.6s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=   0.7s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=   0.6s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=   0.7s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=   0.6s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=   0.6s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.7s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.7s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.7s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   0.5s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   0.6s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   0.6s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   0.5s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   0.6s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   0.6s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   0.5s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   0.6s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   0.6s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   0.5s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25, total=   0.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25, total=   0.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25, total=   0.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25, total=   0.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25, total=   0.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25, total=   0.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25, total=   0.8s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25, total=   0.8s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25, total=   0.8s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=25, total=   0.7s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:   58.1s finished
# RandomizedSearchCV(cv=10, estimator=RandomForestRegressor(random_state=101),
#                    n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=56, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
predictions = rr_random.predict(test_x)

# %%
predictions
# Out:
# array([ 0.43006667, 10.96466667,  4.86583333,  0.21756667,  7.64753333,
#         6.43833333,  1.06996667,  0.576     ,  0.47223333,  6.70266667,
#         7.90303333,  1.0733    ,  8.42826667,  0.45506667,  5.382     ,
#         2.6225    ,  1.15553333, 13.8099    ,  0.47606667,  1.55186667,
#         0.36093333,  8.21886667,  4.73683333,  2.7575    ,  0.501     ,
#         3.551     ,  5.30533333,  3.17533333,  1.19546667,  1.16293333,
#         0.42926667, 10.18963333,  0.4617    ,  2.5805    ,  7.7769    ,
#         4.20483333,  6.27863333,  6.40066667,  2.6375    ,  6.76263333,
#         4.3657    ,  3.54106667,  4.95383333,  0.56763333,  6.28766667,
#         0.76396667,  8.5155    ,  7.0508    ,  2.94533333,  3.58016667,
#         5.01266667,  1.5249    , 21.58243333, 20.4115    ,  6.55016667,
#        10.49533333,  5.1055    ,  8.80203333,  2.675     ,  6.91673333,
#         0.24276667])

# %%
sns.distplot(test_y-predictions)

# %%
plt.scatter(test_y,predictions)

# %%
import pickle
# open a file wfere I want to store the data
file = open('random_forest_regression_model.pkl','wb')

#dump information to that file
pickle.dump(rr_random,file)
